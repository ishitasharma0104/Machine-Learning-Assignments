# %%
#Q1
def clean(city):
  city=city.strip().title()
  return city
  
print(clean(" nEw dELhi "))
# Out:
# New Delhi

# %%
#Q2

# %%
# Q3

# %%
# Q4

# %%
# Q5

# %%
# Q6

# %%
# Q7

# %%
# Q8

# %%
# Q9

# %%
# Q10
