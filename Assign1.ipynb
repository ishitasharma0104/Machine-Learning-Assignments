# %%
# Q1
def valide(input):
  input=input.strip()
  if len(input)>=5 and input.isalnum():
     return input.lower()
  else:
     return "Invalid"
print(valide(" CodeMaster99 "))
print(valide(" Python_Dev "))
# Out:
# codemaster99
# Invalid

# %%
# Q2

# %%
# Q3

# %%
# Q4

# %%
# Q5

# %%
# Q6

# %%
# Q7

# %%
# Q8

# %%
# Q9

# %%
# Q10
